# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.imdb.com/list/ls068082370/"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

soup.title.string
soup.find('h1')
soup.find_all('a')
# Out:
# [<a href="/?ref_=nv_home"><svg class="ipc-logo WNY8DBPCS1ZbiSd7NoqdP" height="56" version="1.1" viewbox="0 0 64 32" width="98" xmlns="http://www.w3.org/2000/svg"><g fill="#F5C518"><rect height="100%" rx="4" width="100%" x="0" y="0"></rect></g><g fill="#000000" fill-rule="nonzero" transform="translate(8.000000, 7.000000)"><polygon points="0 18 5 18 5 0 0 0"></polygon><path d="M15.6725178,0 L14.5534833,8.40846934 L13.8582008,3.83502426 C13.65661,2.37009263 13.4632474,1.09175121 13.278113,0 L7,0 L7,18 L11.2416347,18 L11.2580911,6.11380679 L13.0436094,18 L16.0633571,18 L17.7583653,5.8517865 L17.7707076,18 L22,18 L22,0 L15.6725178,0 Z"></path><path d="M24,18 L24,0 L31.8045586,0 C33.5693522,0 35,1.41994415 35,3.17660424 L35,14.8233958 C35,16.5777858 33.5716617,18 31.8045586,18 L24,18 Z M29.8322479,3.2395236 C29.6339219,3.13233348 29.2545158,3.08072342 28.7026524,3.08072342 L28.7026524,14.8914865 C29.4312846,14.8914865 29.8796736,14.7604764 30.0478195,14.4865461 C30.2159654,14.2165858 30.30
# ...

# %%
paragraph = soup.find("p")
articles = soup.find_all("article")

# %%
paragraph
# Out:
# <p>Top 250 Movies as voted for by IMDb users</p>

# %%
item = soup.find(href="/title/tt0468569/")
item
# Out:
# <a href="/title/tt0468569/"> <img alt="The Dark Knight" class="loadlate" data-tconst="tt0468569" height="209" loadlate="https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UY209_CR0,0,140,209_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB466725069_.png" width="140"/>
# </a>

# %%
items = soup.find_all("span", class_="ipl-rating-star__rating")
items
# Out:
# [<span class="ipl-rating-star__rating">9.3</span>,
#  <span class="ipl-rating-star__rating">0</span>,
#  <span class="ipl-rating-star__rating">Rate</span>,
#  <span class="ipl-rating-star__rating">1</span>,
#  <span class="ipl-rating-star__rating">Rate</span>,
#  <span class="ipl-rating-star__rating">2</span>,
#  <span class="ipl-rating-star__rating">Rate</span>,
#  <span class="ipl-rating-star__rating">3</span>,
#  <span class="ipl-rating-star__rating">Rate</span>,
#  <span class="ipl-rating-star__rating">4</span>,
#  <span class="ipl-rating-star__rating">Rate</span>,
#  <span class="ipl-rating-star__rating">5</span>,
#  <span class="ipl-rating-star__rating">Rate</span>,
#  <span class="ipl-rating-star__rating">6</span>,
#  <span class="ipl-rating-star__rating">Rate</span>,
#  <span class="ipl-rating-star__rating">7</span>,
#  <span class="ipl-rating-star__rating">Rate</span>,
#  <span class="ipl-rating-star__rating">8</span>,
#  <span class="ipl-rating-star__rating">Rate</span>,
# ...

# %%
## Exercise: Scraping http://books.toscrape.com
