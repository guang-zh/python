# %%
# keep graphs inside the notebook, not popping up in a new window
# %matplotlib inline  

import numpy as np
import pandas as pd
import matplotlib

# %%
pwd
# Out:
# 'C:\\Users\\1\\Desktop\\le-wagon-exercises'

# %%
file = "countries.csv"

# %%
countries_df = pd.read_csv(file, decimal=',')

# %%
countries_df
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0            647500                        48.0                          0.00
# 1             28748                       124.6                          1.26
# 2           2381740                        13.8                          0.04
# 3               199                       290.4                         58.29
# 4               468                       152.1                          0.00
# ..              ...                         ...                           ...
# 222            5860                       419.9                          0.00
# 223          266000                         1.0                          0.42
# 224          527970                        40.6                          0.36
# 225          752614                        15.3                          0.00
# 226          390580                        31.3                          0.00
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0            23.06                              163.07               700.0
# 1            -4.93                               21.52              4500.0
# 2            -0.39                               31.00              6000.0
# 3           -20.71                                9.27              8000.0
# 4             6.60                                4.05             19000.0
# ..             ...                                 ...                 ...
# 222           2.98                               19.62               800.0
# 223            NaN                                 NaN                 NaN
# 224           0.00                               61.50               800.0
# 225           0.00                               88.29               800.0
# 226           0.00                               67.69              1900.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 0            36.0                3.2       12.13       0.22      87.65
# 1            86.5               71.2       21.09       4.42      74.49
# 2            70.0               78.1        3.22       0.25      96.53
# 3            97.0              259.5       10.00      15.00      75.00
# 4           100.0              497.2        2.22       0.00      97.78
# ..            ...                ...         ...        ...        ...
# 222           NaN              145.2       16.90      18.97      64.13
# 223           NaN                NaN        0.02       0.00      99.98
# 224          50.2               37.2        2.78       0.24      96.98
# 225          80.6                8.2        7.08       0.03      92.90
# 226          90.7               26.8        8.32       0.34      91.34
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 0        1.0      46.60      20.34         0.38      0.24     0.38
# 1        3.0      15.11       5.22       232.00    188.00   579.00
# 2        1.0      17.14       4.61       101.00      0.60   298.00
# 3        2.0      22.46       3.27          NaN       NaN      NaN
# 4        3.0       8.71       6.25          NaN       NaN      NaN
# ..       ...        ...        ...          ...       ...      ...
# 222      3.0      31.67       3.92         0.09      0.28     0.63
# 223      1.0        NaN        NaN          NaN       NaN     0.40
# 224      1.0      42.89       8.30       135.00    472.00   393.00
# 225      2.0      41.00      19.93         0.22      0.29   489.00
# 226      2.0      28.01      21.84       179.00    243.00   579.00
#
# [227 rows x 20 columns]

# %%
countries_df.shape
# Out:
# (227, 20)

# %%
countries_df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
countries_df.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# Service                               float64
# dtype: object

# %%
countries_df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
countries_df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0          23.06                              163.07               700.0
# 1          -4.93                               21.52              4500.0
# 2          -0.39                               31.00              6000.0
# 3         -20.71                                9.27              8000.0
# 4           6.60                                4.05             19000.0
#
#    Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# 0          36.0                3.2       12.13       0.22      87.65      1.0
# 1          86.5               71.2       21.09       4.42      74.49      3.0
# 2          70.0               78.1        3.22       0.25      96.53      1.0
# 3          97.0              259.5       10.00      15.00      75.00      2.0
# 4         100.0              497.2        2.22       0.00      97.78      3.0
#
#    Birthrate  Deathrate  Agriculture  Industry  Service
# 0      46.60      20.34         0.38      0.24     0.38
# 1      15.11       5.22       232.00    188.00   579.00
# 2      17.14       4.61       101.00      0.60   298.00
# 3      22.46       3.27          NaN       NaN      NaN
# 4       8.71       6.25          NaN       NaN      NaN

# %%
countries_df.tail()
# Out:
#              Country                               Region  Population  \
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 222            5860                       419.9                          0.00
# 223          266000                         1.0                          0.42
# 224          527970                        40.6                          0.36
# 225          752614                        15.3                          0.00
# 226          390580                        31.3                          0.00
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 222           2.98                               19.62               800.0
# 223            NaN                                 NaN                 NaN
# 224           0.00                               61.50               800.0
# 225           0.00                               88.29               800.0
# 226           0.00                               67.69              1900.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 222           NaN              145.2       16.90      18.97      64.13
# 223           NaN                NaN        0.02       0.00      99.98
# 224          50.2               37.2        2.78       0.24      96.98
# 225          80.6                8.2        7.08       0.03      92.90
# 226          90.7               26.8        8.32       0.34      91.34
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 222      3.0      31.67       3.92         0.09      0.28     0.63
# 223      1.0        NaN        NaN          NaN       NaN     0.40
# 224      1.0      42.89       8.30       135.00    472.00   393.00
# 225      2.0      41.00      19.93         0.22      0.29   489.00
# 226      2.0      28.01      21.84       179.00    243.00   579.00

# %%
countries_df["Country"]
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 222         West Bank
# 223    Western Sahara
# 224             Yemen
# 225            Zambia
# 226          Zimbabwe
# Name: Country, Length: 227, dtype: object

# %%
countries_df[5:10]
# Out:
#               Country                               Region  Population  \
# 5             Angola   SUB-SAHARAN AFRICA                     12127071
# 6           Anguilla               LATIN AMER. & CARIB           13477
# 7  Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8          Argentina               LATIN AMER. & CARIB        39921833
# 9            Armenia                  C.W. OF IND. STATES      2976372
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 5         1246700                         9.7                          0.13
# 6             102                       132.1                         59.80
# 7             443                       156.0                         34.54
# 8         2766890                        14.4                          0.18
# 9           29800                        99.9                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 5           0.00                              191.19              1900.0
# 6          10.76                               21.03              8600.0
# 7          -6.15                               19.46             11000.0
# 8           0.61                               15.18             11200.0
# 9          -6.47                               23.28              3500.0
#
#    Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# 5          42.0                7.8        2.41       0.24      97.35      NaN
# 6          95.0              460.0        0.00       0.00     100.00      2.0
# 7          89.0              549.9       18.18       4.55      77.27      2.0
# 8          97.1              220.4       12.31       0.48      87.21      3.0
# 9          98.6              195.7       17.55       2.30      80.15      4.0
#
#    Birthrate  Deathrate  Agriculture  Industry  Service
# 5      45.11      24.20        96.00    658.00   246.00
# 6      14.17       5.34         0.04      0.18     0.78
# 7      16.93       5.37        38.00      0.22   743.00
# 8      16.73       7.55        95.00    358.00   547.00
# 9      12.07       8.23       239.00    343.00   418.00

# %%
countries_df.loc[0,"Country"]
# Out:
# 'Afghanistan '

# %%
# df.loc[row_indexer, column_indexer]
# for example:
countries_df.loc[21,"Country"]
# Out:
# 'Benin '

# %%
american = countries_df['Region'].str.contains('AMER')
countries_df[american].head()
# Out:
#                Country                   Region  Population  Area (sq. mi.)  \
# 6            Anguilla   LATIN AMER. & CARIB           13477             102
# 7   Antigua & Barbuda   LATIN AMER. & CARIB           69108             443
# 8           Argentina   LATIN AMER. & CARIB        39921833         2766890
# 10              Aruba   LATIN AMER. & CARIB           71891             193
# 14       Bahamas, The   LATIN AMER. & CARIB          303770           13940
#
#     Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 6                        132.1                         59.80          10.76
# 7                        156.0                         34.54          -6.15
# 8                         14.4                          0.18           0.61
# 10                       372.5                         35.49           0.00
# 14                        21.8                         25.41          -2.20
#
#     Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 6                                21.03              8600.0          95.0
# 7                                19.46             11000.0          89.0
# 8                                15.18             11200.0          97.1
# 10                                5.89             28000.0          97.0
# 14                               25.21             16700.0          95.6
#
#     Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 6               460.0        0.00       0.00     100.00      2.0      14.17
# 7               549.9       18.18       4.55      77.27      2.0      16.93
# 8               220.4       12.31       0.48      87.21      3.0      16.73
# 10              516.1       10.53       0.00      89.47      2.0      11.03
# 14              460.6        0.80       0.40      98.80      2.0      17.57
#
#     Deathrate  Agriculture  Industry  Service
# 6        5.34         0.04      0.18     0.78
# 7        5.37        38.00      0.22   743.00
# 8        7.55        95.00    358.00   547.00
# 10       6.68         4.00    333.00   663.00
# 14       9.05         0.03      0.07     0.90

# %%
# Using .isin() for filter
countries_df["Region"].isin(["WESTERN EUROPE", "EASTERN EUROPE"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# Name: Region, Length: 227, dtype: bool

# %%
countries_df["Region"] = countries_df["Region"].map(str.strip)

# %%
countries_df["Region"].head()
# Out:
# 0    ASIA (EX. NEAR EAST)
# 1          EASTERN EUROPE
# 2         NORTHERN AFRICA
# 3                 OCEANIA
# 4          WESTERN EUROPE
# Name: Region, dtype: object

# %%
# Using .isin() for filter
countries_df["Region"].isin(["WESTERN EUROPE", "EASTERN EUROPE"])
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 222    False
# 223    False
# 224    False
# 225    False
# 226    False
# Name: Region, Length: 227, dtype: bool

# %%
# Filtering columns
# pd.DataFrame.filter()
countries_df.filter(items=['Country', 'Population'])
# Out:
#              Country  Population
# 0       Afghanistan     31056997
# 1           Albania      3581655
# 2           Algeria     32930091
# 3    American Samoa        57794
# 4           Andorra        71201
# ..               ...         ...
# 222       West Bank      2460492
# 223  Western Sahara       273008
# 224           Yemen     21456188
# 225          Zambia     11502010
# 226        Zimbabwe     12236805
#
# [227 rows x 2 columns]

# %%
# Re-indexing
countries_df = countries_df.set_index('Country')

# %%
# Notice the bolding is difference. As now, bolding on Country names
countries_df.head()
# Out:
#                                Region  Population  Area (sq. mi.)  \
# Country
# Afghanistan      ASIA (EX. NEAR EAST)    31056997          647500
# Albania                EASTERN EUROPE     3581655           28748
# Algeria               NORTHERN AFRICA    32930091         2381740
# American Samoa                OCEANIA       57794             199
# Andorra                WESTERN EUROPE       71201             468
#
#                  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# Country
# Afghanistan                            48.0                          0.00
# Albania                               124.6                          1.26
# Algeria                                13.8                          0.04
# American Samoa                        290.4                         58.29
# Andorra                               152.1                          0.00
#
#                  Net migration  Infant mortality (per 1000 births)  \
# Country
# Afghanistan              23.06                              163.07
# Albania                  -4.93                               21.52
# Algeria                  -0.39                               31.00
# American Samoa          -20.71                                9.27
# Andorra                   6.60                                4.05
#
#                  GDP ($ per capita)  Literacy (%)  Phones (per 1000)  \
# Country
# Afghanistan                   700.0          36.0                3.2
# Albania                      4500.0          86.5               71.2
# Algeria                      6000.0          70.0               78.1
# American Samoa               8000.0          97.0              259.5
# Andorra                     19000.0         100.0              497.2
#
#                  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# Country
# Afghanistan           12.13       0.22      87.65      1.0      46.60
# Albania               21.09       4.42      74.49      3.0      15.11
# Algeria                3.22       0.25      96.53      1.0      17.14
# American Samoa        10.00      15.00      75.00      2.0      22.46
# Andorra                2.22       0.00      97.78      3.0       8.71
#
#                  Deathrate  Agriculture  Industry  Service
# Country
# Afghanistan          20.34         0.38      0.24     0.38
# Albania               5.22       232.00    188.00   579.00
# Algeria               4.61       101.00      0.60   298.00
# American Samoa        3.27          NaN       NaN      NaN
# Andorra               6.25          NaN       NaN      NaN

# %%
countries_df.sort_values('Population', ascending=False)
# Out:
#                                      Region  Population  Area (sq. mi.)  \
# Country
# China                  ASIA (EX. NEAR EAST)  1313973713         9596960
# India                  ASIA (EX. NEAR EAST)  1095351995         3287590
# United States              NORTHERN AMERICA   298444215         9631420
# Indonesia              ASIA (EX. NEAR EAST)   245452739         1919440
# Brazil                  LATIN AMER. & CARIB   188078227         8511965
# ...                                     ...         ...             ...
# Nauru                               OCEANIA       13287              21
# Tuvalu                              OCEANIA       11810              26
# Montserrat              LATIN AMER. & CARIB        9439             102
# Saint Helena             SUB-SAHARAN AFRICA        7502             413
# St Pierre & Miquelon       NORTHERN AMERICA        7026             242
#
#                        Pop. Density (per sq. mi.)  \
# Country
# China                                       136.9
# India                                       333.2
# United States                                31.0
# Indonesia                                   127.9
# Brazil                                       22.1
# ...                                           ...
# Nauru                                       632.7
# Tuvalu                                      454.2
# Montserrat                                   92.5
# Saint Helena                                 18.2
# St Pierre & Miquelon                         29.0
#
#                        Coastline (coast/area ratio)  Net migration  \
# Country
# China                                          0.15          -0.40
# India                                          0.21          -0.07
# United States                                  0.21           3.41
# Indonesia                                      2.85           0.00
# Brazil                                         0.09          -0.03
# ...                                             ...            ...
# Nauru                                        142.86           0.00
# Tuvalu                                        92.31           0.00
# Montserrat                                    39.22           0.00
# Saint Helena                                  14.53           0.00
# St Pierre & Miquelon                          49.59          -4.86
#
#                        Infant mortality (per 1000 births)  GDP ($ per capita)  \
# Country
# China                                               24.18              5000.0
# India                                               56.29              2900.0
# United States                                        6.50             37800.0
# Indonesia                                           35.60              3200.0
# Brazil                                              29.61              7600.0
# ...                                                   ...                 ...
# Nauru                                                9.95              5000.0
# Tuvalu                                              20.03              1100.0
# Montserrat                                           7.35              3400.0
# Saint Helena                                        19.00              2500.0
# St Pierre & Miquelon                                 7.54              6900.0
#
#                        Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  \
# Country
# China                          90.9              266.7       15.40       1.25
# India                          59.5               45.4       54.40       2.74
# United States                  97.0              898.0       19.13       0.22
# Indonesia                      87.9               52.0       11.32       7.23
# Brazil                         86.4              225.3        6.96       0.90
# ...                             ...                ...         ...        ...
# Nauru                           NaN              143.0        0.00       0.00
# Tuvalu                          NaN               59.3        0.00       0.00
# Montserrat                     97.0                NaN       20.00       0.00
# Saint Helena                   97.0              293.3       12.90       0.00
# St Pierre & Miquelon           99.0              683.2       13.04       0.00
#
#                        Other (%)  Climate  Birthrate  Deathrate  Agriculture  \
# Country
# China                      83.35      1.5      13.25       6.97       125.00
# India                      42.86      2.5      22.01       8.18       186.00
# United States              80.65      3.0      14.14       8.26         0.01
# Indonesia                  81.45      2.0      20.34       6.25       134.00
# Brazil                     92.15      2.0      16.56       6.17        84.00
# ...                          ...      ...        ...        ...          ...
# Nauru                     100.00      2.0      24.76       6.70          NaN
# Tuvalu                    100.00      2.0      22.18       7.11       166.00
# Montserrat                 80.00      2.0      17.59       7.10          NaN
# Saint Helena               87.10      NaN      12.13       6.53          NaN
# St Pierre & Miquelon       86.96      NaN      13.52       6.83          NaN
#
#                        Industry  Service
# Country
# China                     473.0    403.0
# India                     276.0    538.0
# United States             204.0    787.0
# Indonesia                 458.0    408.0
# Brazil                      0.4    516.0
# ...                         ...      ...
# Nauru                       NaN      NaN
# Tuvalu                    272.0    562.0
# Montserrat                  NaN      NaN
# Saint Helena                NaN      NaN
# St Pierre & Miquelon        NaN      NaN
#
# [227 rows x 19 columns]

# %%
countries_df.sort_values('Population', ascending=False)\
    .filter(items=['Region','Population','Area (sq. mi.)'])\
    .head(10)
# Out:
#                               Region  Population  Area (sq. mi.)
# Country
# China           ASIA (EX. NEAR EAST)  1313973713         9596960
# India           ASIA (EX. NEAR EAST)  1095351995         3287590
# United States       NORTHERN AMERICA   298444215         9631420
# Indonesia       ASIA (EX. NEAR EAST)   245452739         1919440
# Brazil           LATIN AMER. & CARIB   188078227         8511965
# Pakistan        ASIA (EX. NEAR EAST)   165803560          803940
# Bangladesh      ASIA (EX. NEAR EAST)   147365352          144000
# Russia           C.W. OF IND. STATES   142893540        17075200
# Nigeria           SUB-SAHARAN AFRICA   131859731          923768
# Japan           ASIA (EX. NEAR EAST)   127463611          377835

# %%
## Grouping

# %%
regions = countries_df.groupby('Region')
regions

# %%
regions[['Population','Area (sq. mi.)']].sum()
# Out:
#                       Population  Area (sq. mi.)
# Region
# ASIA (EX. NEAR EAST)  3687982236        23096712
# BALTICS                  7184974          175015
# C.W. OF IND. STATES    280081548        22100843
# EASTERN EUROPE         119914717         1152222
# LATIN AMER. & CARIB    561824599        20544084
# NEAR EAST              195068377         4355586
# NORTHERN AFRICA        161407133         6018890
# NORTHERN AMERICA       331672307        21782471
# OCEANIA                 33131662         8519812
# SUB-SAHARAN AFRICA     749437000        24341406
# WESTERN EUROPE         396339998         3710478

# %%
regions[['Pop. Density (per sq. mi.)']].mean()\
    .sort_values('Pop. Density (per sq. mi.)', ascending=False)\
    .round(1)
# Out:
#                       Pop. Density (per sq. mi.)
# Region
# ASIA (EX. NEAR EAST)                      1264.8
# WESTERN EUROPE                             952.0
# NEAR EAST                                  427.1
# NORTHERN AMERICA                           260.9
# LATIN AMER. & CARIB                        136.2
# OCEANIA                                    131.2
# EASTERN EUROPE                             100.9
# SUB-SAHARAN AFRICA                          92.3
# C.W. OF IND. STATES                         56.7
# BALTICS                                     39.8
# NORTHERN AFRICA                             38.9

# %%
regions.agg({
    'Population': np.sum,
    'GDP ($ per capita)': np.mean
}).round(1).sort_values('GDP ($ per capita)', ascending=False)
# Out:
#                       Population  GDP ($ per capita)
# Region
# WESTERN EUROPE         396339998             27046.4
# NORTHERN AMERICA       331672307             26100.0
# BALTICS                  7184974             11300.0
# NEAR EAST              195068377             10456.2
# EASTERN EUROPE         119914717              9808.3
# LATIN AMER. & CARIB    561824599              8682.2
# OCEANIA                 33131662              8247.6
# ASIA (EX. NEAR EAST)  3687982236              8053.6
# NORTHERN AFRICA        161407133              5460.0
# C.W. OF IND. STATES    280081548              4000.0
# SUB-SAHARAN AFRICA     749437000              2323.5

# %%
big_population = countries_df['Population']>100000000
countries_df[big_population]
# Out:
#                               Region  Population  Area (sq. mi.)  \
# Country
# Bangladesh      ASIA (EX. NEAR EAST)   147365352          144000
# Brazil           LATIN AMER. & CARIB   188078227         8511965
# China           ASIA (EX. NEAR EAST)  1313973713         9596960
# India           ASIA (EX. NEAR EAST)  1095351995         3287590
# Indonesia       ASIA (EX. NEAR EAST)   245452739         1919440
# Japan           ASIA (EX. NEAR EAST)   127463611          377835
# Mexico           LATIN AMER. & CARIB   107449525         1972550
# Nigeria           SUB-SAHARAN AFRICA   131859731          923768
# Pakistan        ASIA (EX. NEAR EAST)   165803560          803940
# Russia           C.W. OF IND. STATES   142893540        17075200
# United States       NORTHERN AMERICA   298444215         9631420
#
#                 Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# Country
# Bangladesh                          1023.4                          0.40
# Brazil                                22.1                          0.09
# China                                136.9                          0.15
# India                                333.2                          0.21
# Indonesia                            127.9                          2.85
# Japan                                337.4                          7.87
# Mexico                                54.5                          0.47
# Nigeria                              142.7                          0.09
# Pakistan                             206.2                          0.13
# Russia                                 8.4                          0.22
# United States                         31.0                          0.21
#
#                 Net migration  Infant mortality (per 1000 births)  \
# Country
# Bangladesh              -0.71                               62.60
# Brazil                  -0.03                               29.61
# China                   -0.40                               24.18
# India                   -0.07                               56.29
# Indonesia                0.00                               35.60
# Japan                    0.00                                3.26
# Mexico                  -4.87                               20.91
# Nigeria                  0.26                               98.80
# Pakistan                -2.77                               72.44
# Russia                   1.02                               15.39
# United States            3.41                                6.50
#
#                 GDP ($ per capita)  Literacy (%)  Phones (per 1000)  \
# Country
# Bangladesh                  1900.0          43.1                7.3
# Brazil                      7600.0          86.4              225.3
# China                       5000.0          90.9              266.7
# India                       2900.0          59.5               45.4
# Indonesia                   3200.0          87.9               52.0
# Japan                      28200.0          99.0              461.2
# Mexico                      9000.0          92.2              181.6
# Nigeria                      900.0          68.0                9.3
# Pakistan                    2100.0          45.7               31.8
# Russia                      8900.0          99.6              280.6
# United States              37800.0          97.0              898.0
#
#                 Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# Country
# Bangladesh           62.11       3.07      34.82      2.0      29.80
# Brazil                6.96       0.90      92.15      2.0      16.56
# China                15.40       1.25      83.35      1.5      13.25
# India                54.40       2.74      42.86      2.5      22.01
# Indonesia            11.32       7.23      81.45      2.0      20.34
# Japan                12.19       0.96      86.85      3.0       9.37
# Mexico               12.99       1.31      85.70      1.5      20.69
# Nigeria              31.29       2.96      65.75      1.5      40.43
# Pakistan             27.87       0.87      71.26      1.0      29.74
# Russia                7.33       0.11      92.56      NaN       9.95
# United States        19.13       0.22      80.65      3.0      14.14
#
#                 Deathrate  Agriculture  Industry  Service
# Country
# Bangladesh           8.27       199.00     198.0    603.0
# Brazil               6.17        84.00       0.4    516.0
# China                6.97       125.00     473.0    403.0
# India                8.18       186.00     276.0    538.0
# Indonesia            6.25       134.00     458.0    408.0
# Japan                9.16        17.00     258.0    725.0
# Mexico               4.74        38.00     259.0    702.0
# Nigeria             16.94       269.00     487.0    244.0
# Pakistan             8.23       216.00     251.0    533.0
# Russia              14.65        54.00     371.0    575.0
# United States        8.26         0.01     204.0    787.0

# %% [markdown]
# # Plotting data

# %%
# %matplotlib inline
import matplotlib

# %%
column='GDP ($ per capita)'
top_ten_countries_df = countries_df[[column]]\
    .sort_values(column, ascending=False)\
    .head(10)

# %%
top_ten_countries_df.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Country'>
